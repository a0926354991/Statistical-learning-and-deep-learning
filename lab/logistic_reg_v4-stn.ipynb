# %% [markdown]
# ## In-class hands-on activity: Logistic Regression
#
# Part 1: Logistic regression using simulated data
#
# Part 2: Heart Failure Prediction
# Original dataset from <https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction/data>
#
# In-class exercise: Fitting logistic regression and compute performance.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing

# %matplotlib inline

pd.set_option('display.max_column', 500)
pd.set_option('display.max_rows', 5000)
random.seed(1001)
np.random.seed(1001)

# %% [markdown]
# ### Part 1: Simulated Data for two variable case

# %%
# Class 1 centered at (1, 1), class 0 centered at (-1, -1)
#    Std dev for two features are 2.5, 2.2

# number of class 1 data points
n1 = 20
# number of class 0 data points
n0 = 20

mean1 = np.array([1, 1])
cov1 = np.array([[2.5, 0.3],
                [0.3, 2.2]])

mean0 = np.array([-1, -1])
cov0 = np.array([[2.5, 0.3],
                [0.3, 2.2]])

# generate class1
train1 = np.random.multivariate_normal(mean1, cov1, n1)
# generate class0
train0 = np.random.multivariate_normal(mean0, cov0, n0)

# combine the two class
train = np.vstack((train1, train0))
df_train = pd.DataFrame.from_records(train)
df_train.columns = ("x1", "x2")
# assign the label
df_train['label'] = 1
df_train.iloc[n1:, 2] = 0

# %%
sns.scatterplot(data=df_train, x="x1", y="x2", hue="label")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### TODO
# Use `linear_model.LogisticRegression` to fit a ridge Logistic regression. The regularization coefficient is set to `C=1000`. Store the fitted model in `clf0`. Print the coefficients and Intercept.

# %%
clf0 = linear_model.LogisticRegression(C=1000)
clf0.fit(train,df_train.label.values)
print(f"Coefficient: {clf0.coef_}")
print(f" Intercept: {clf0.intercept_}")

clf0.decision_function
# Out:
# Coefficient: [[1.21182284 1.02067065]]
#  Intercept: [0.63376563]
# <bound method LinearClassifierMixin.decision_function of LogisticRegression(C=1000)>

# %% [markdown]
# ### Sanity Check
# <pre>
# Coefficient: [[1.21182284 1.02067065]]
#  Intercept: [0.63376563]
# </pre>

# %% [markdown]
# ====
#
# Visualize the predicted probability based on the fitted model.
# We are generating grids in a [-5, 5] X [-5, 5] space and compute the fitted probability for each data point.

# %%
xx, yy = np.mgrid[-5:5:.01, -5:5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
prob0 = clf0.predict_proba(grid)[:, 1]
probs = prob0.reshape(xx.shape)

# %% [markdown]
# ### Plot the probability.

# %%
f, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)

# %%
# a simple way to identify the classification boundary
idx = np.abs(prob0 - 0.5) < 0.01
subgrid = grid[idx]
plt.plot(subgrid[:,0], subgrid[:,1])

# plot the data points and color them.
plt.scatter(train1[:,0], train1[:,1], color = "black")
plt.scatter(train0[:,0], train0[:,1], color = "red")

# %% [markdown]
# ###  Part 2: 資料說明 (From the original data provider)
#
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Four out of 5CVD deaths are due to heart attacks and strokes, and one-third of these deaths occur prematurely in people under 70 years of age. Heart failure is a common event caused by CVDs and this dataset contains 11 features that can be used to predict a possible heart disease.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help.
#
# ### Attribute Information
# * Age: age of the patient [years]
# * Sex: sex of the patient [M: Male, F: Female]
# * ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# * RestingBP: resting blood pressure [mm Hg]
# * Cholesterol: serum cholesterol [mm/dl]
# * FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# * RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# * MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# * ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# * Oldpeak: oldpeak = ST [Numeric value measured in depression]
# * ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# * HeartDisease: output class [1: heart disease, 0: Normal]

# %%
# Start with data loading and showing sample data
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# make sure the data types are reasonable
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.HeartDisease.value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
cat_cols = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
df_wc=pd.get_dummies(df,columns=cat_cols, drop_first=False)
df_wc.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0  False   True              False               True              False
# 1   True  False              False              False               True
# 2  False   True              False               True              False
# 3   True  False               True              False              False
# 4  False   True              False              False               True
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0             False           False               True          False
# 1             False           False               True          False
# 2             False           False              False           True
# 3             False           False               True          False
# 4             False           False               True          False
#
#    ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 0              True             False          False          False
# 1              True             False          False           True
# 2              True             False          False          False
# 3             False              True          False           True
# 4              True             False          False          False
#
#    ST_Slope_Up
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True

# %%
# split training and test

mask1 = np.random.rand(len(df_wc)) < 0.9
df_wc_train = df_wc[mask1].copy()
df_wc_test = df_wc[~mask1].copy()

target = 'HeartDisease'
featnames = df_wc.columns.to_list()
featnames.remove(target)

print("Features to be include in the model", featnames)
# Out:
# Features to be include in the model ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat', 'ST_Slope_Up']

# %%
X_train = df_wc_train[featnames].values
y_train = df_wc_train[target].values

X_test = df_wc_test[featnames].values
y_test = df_wc_test[target].values

mm_scaler=preprocessing.MinMaxScaler()
X_train=mm_scaler.fit_transform(X_train)
X_test=mm_scaler.transform(X_test)

# %% [markdown]
# ### TODO
#
# * What will happen to binary features and numerical features after applying MinMaxScalar()?
# * Verify that X_train and X_test has been properly scaled.

# %%
print(f"The shape of X_train is {X_train.shape}")
xmin1 = X_train.min(axis=0)
xmax1 = X_train.max(axis=0)
xmean1 = X_train.mean(axis=0)

xmmm1 = np.vstack((xmin1, xmax1, xmean1))
print("The min, max, and mean for X_train")
print(xmmm1.T)
                  

print(f"The shape of X_test is {X_test.shape}")
xmin2 = X_test.min(axis=0)
xmax2 = X_test.max(axis=0)
xmean2 = X_test.mean(axis=0)

xmmm2 = np.vstack((xmin2, xmax2, xmean2))
print("The min, max, and mean for X_test")
print(xmmm2.T)
# Out:
# The shape of X_train is (850, 20)
# The min, max, and mean for X_train
# [[0.         1.         0.52184874]
#  [0.         1.         0.66214118]
#  [0.         1.         0.33056873]
#  [0.         1.         0.22470588]
#  [0.         1.         0.54098592]
#  [0.         1.         0.38170279]
#  [0.         1.         0.20823529]
#  [0.         1.         0.79176471]
#  [0.         1.         0.53529412]
#  [0.         1.         0.18941176]
#  [0.         1.         0.22705882]
#  [0.         1.         0.04823529]
#  [0.         1.         0.20588235]
#  [0.         1.         0.6       ]
#  [0.         1.         0.19411765]
#  [0.         1.         0.59647059]
#  [0.         1.         0.40352941]
#  [0.         1.         0.07294118]
#  [0.         1.         0.48941176]
#  [0.         1.         0.43764706]]
# The shape of X_test is (68, 20)
# The min, max, and mean for X_test
# [[ 0.06122449  0.89795918  0.50540216]
#  [ 0.5         0.925       0.66      ]
#  [ 0.          0.85903814  0.31862745]
#  [ 0.          1.          0.33823529]
#  [ 0.08450704  0.91549296  0.53997514]
#  [-0.07894737  1.07894737  0.35758514]
#  [ 0.          1.          0.23529412]
#  [ 0.          1.          0.76470588]
#  [ 0.          1.          0.60294118]
#  [ 0.          1.          0.17647059]
#  [ 0.          1.          0.14705882]
#  [ 0.          1.          0.07352941]
#  [ 0.          1.          0.19117647]
#  [ 0.          1.          0.61764706]
#  [ 0.          1.          0.19117647]
#  [ 0.          1.          0.58823529]
#  [ 0.          1.          0.41176471]
#  [ 0.          1.          0.01470588]
#  [ 0.          1.          0.64705882]
#  [ 0.          1.          0.33823529]]

# %% [markdown]
# ### --- remove below ---
# ### Discussion for this TODO
#
# We can see that for X_test, the minimal and maximum values for each features may not be exactly 0 and 1. This is reasonable because the unseen data in the test set may have a slightly different data range. However, given that we have split training and test randomly, and the dataset size is large enough, we should see the data range in the test set lie closely to 0 and 1.
#
# ### --- remove above ---

# %% [markdown]
# ### Fitting Logistic Regression
#
# Use linear_model.LogisticRegressionCV() to fit a logistic regression model to the training data. Use metrics.classification_report() to compute prediction performance. Answer the following questions.
#
# 1. List first five coefficients and their feature names.
# 2. Interpret the meanings of these feature coefficients.
# 3. Show the regularization coefficient selected by the CV routine.
# 4. Apply the model to predict the test set. What is the accuracy, precision, and recall?

# %%
clf=linear_model.LogisticRegressionCV()
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)


print("First five features and coefficients")
for coef, fname in zip(clf.coef_.flatten(), featnames[0:5]):
    print(f"{fname:12s}: {coef:.4f}")

print("---")
print(f"The regularization coefficient is {clf.C_[0]:.4f}")

print("---")
print(metrics.classification_report(y_test, y_pred, digits=4))
# Out:
# First five features and coefficients
# Age         : 0.2918
# RestingBP   : 0.0336
# Cholesterol : -0.3425
# FastingBS   : 0.5922
# MaxHR       : -0.2533
# ---
# The regularization coefficient is 0.0464
# ---
#               precision    recall  f1-score   support
#
#            0     0.8000    0.6667    0.7273        24
#            1     0.8333    0.9091    0.8696        44
#
#     accuracy                         0.8235        68
#    macro avg     0.8167    0.7879    0.7984        68
# weighted avg     0.8216    0.8235    0.8193        68

# %% [markdown]
# accuracy = 0.8286
#
# for the positive cases, precision = 0.8136, recall = 0.8727, F1 = 0.8421.

# %% [markdown]
# ### Sanity Check
# <pre>
# First five features and coefficients
# Age         : 0.2918
# RestingBP   : 0.0336
# Cholesterol : -0.3425
# FastingBS   : 0.5922
# MaxHR       : -0.2533
# ---
# The regularization coefficient is 0.0464
# ---
#               precision    recall  f1-score   support
#
#            0     0.8000    0.6667    0.7273        24
#            1     0.8333    0.9091    0.8696        44
#
#     accuracy                         0.8235        68
#    macro avg     0.8167    0.7879    0.7984        68
# weighted avg     0.8216    0.8235    0.8193        68
#
# </pre>
#
#
# <pre>
# accuracy = 0.8286
#
# for the positive cases, precision = 0.8136, recall = 0.8727, F1 = 0.8421.
# </pre>

# %% [markdown]
# ### Compute Accuracy, Precision, Recall, and F1 from scratch.
# Use numpy to do the work. You should not use existing library such as metrics.classification_report().

# %%
acc = np.sum(y_test == y_pred) / y_test.shape[0]
print(f"Accuracy = {acc:.4f}")

# recall
npositive = np.sum(y_test)
recall = np.sum(y_test * y_pred) / npositive
print(f"Recall = {recall:.4f}")

# precision
npredp = np.sum(y_pred)
precision = np.sum(y_test * y_pred) / npredp
print(f"Precision = {precision:.4f}")

# F1
f1 = 2 * precision * recall / (precision + recall)
print(f"F1 score = {f1:.4f}")
# Out:
# Accuracy = 0.8235
# Recall = 0.9091
# Precision = 0.8333
# F1 score = 0.8696

# %% [markdown]
# ### Sanity Check
# <pre>
# Accuracy = 0.8235
# Recall = 0.9091
# Precision = 0.8333
# F1 score = 0.8696
# </pre>

# %% [markdown]
# ### Explore the prediction results
#
# Create a new data frame that contain the following columns (in this order):
# * Pred: the predicted value for test examples
# * Predp: the predicted probability for test examples.
# * HearDisease: the ground truth for the test examples.
# * All the remaining features.
#
# Go through the prediction errors. Think about the following questions.
# 1. Why the model made wrong predictions for certain examples?
# 2. How can we improve the performance?

# %%
y_predprob = clf.predict_proba(X_test)
df_wc_test['Pred'] = y_pred
df_wc_test['Predp'] = y_predprob[:,1]
df_wc_test['Perror'] = 0
df_wc_test.loc[df_wc_test.Pred != df_wc_test.HeartDisease, 'Perror'] = 1


origcol = list(df_wc_test.columns)

headcol = ['Perror', 'Pred', 'Predp', 'HeartDisease']
for aitem in headcol:
    origcol.remove(aitem)
newcol = headcol + origcol

df_wc_test2 = df_wc_test[newcol]

df_wc_test2.sort_values(['Predp'], ascending=True)
# Out:
#      Perror  Pred     Predp  HeartDisease  Age  RestingBP  Cholesterol  \
# 126       0     0  0.053963             0   34        130          161
# 9         0     0  0.061381             0   48        120          284
# 64        0     0  0.062089             0   50        110          202
# 234       0     0  0.070592             0   54        140          309
# 467       0     0  0.076663             0   63        132            0
# 228       0     0  0.119271             0   41        120          295
# 162       0     0  0.125006             0   47        160          263
# 12        0     0  0.128423             0   39        120          204
# 171       0     0  0.131500             0   40        140          235
# 684       1     0  0.142854             1   47        108          243
# 282       0     0  0.166112             0   51        130          220
# 843       0     0  0.167434             0   58        150          283
# 661       1     0  0.176108             1   49        118          149
# 560       0     0  0.178265             0   54        133          203
# 629       0     0  0.196151             0   57        128          303
# 639       0     0  0.244889             0   54        132          288
# 110       0     0  0.307765             0   59        130          188
# 655       1     0  0.322858             1   40        152          223
# 270       0     0  0.344280             0   45        120          225
# 30        1     0  0.474083             1   53        145          518
# 850       0     1  0.508060             1   62        160          164
# 302       0     1  0.554411             1   53        125            0
# 383       0     1  0.576788             1   38        110            0
# 41        0     1  0.578042             1   54        130          294
# 581       0     1  0.586684             1   48        140          208
# 88        0     1  0.589701             1   43        120          291
# 811       1     1  0.620129             0   58        100          248
# 626       1     1  0.622778             0   53        142          226
# 469       1     1  0.641169             0   56        124          224
# 372       0     1  0.649190             1   63        185            0
# 492       0     1  0.668307             1   49        130            0
# 585       0     1  0.678709             1   57        180          285
# 516       0     1  0.681028             1   68        150          195
# 820       1     1  0.701686             0   52        152          298
# 637       1     1  0.737978             0   43        115          303
# 327       0     1  0.763415             1   59        125            0
# 335       0     1  0.765540             1   62        120            0
# 883       1     1  0.770952             0   57        140          192
# 555       0     1  0.771620             1   58        150          219
# 509       0     1  0.779602             1   58        110          198
# 909       0     1  0.789767             1   63        124          197
# 719       0     1  0.795372             1   63        130          254
# 520       1     1  0.807855             0   64        130          223
# 457       0     1  0.853865             1   40        125            0
# 395       0     1  0.855915             1   38        135            0
# 793       0     1  0.857310             1   67        125          254
# 473       0     1  0.861080             1   60        141          316
# 324       0     1  0.871319             1   46        100            0
# 350       0     1  0.872370             1   53        120            0
# 718       0     1  0.872747             1   57        165          289
# 842       0     1  0.874094             1   43        132          341
# 56        0     1  0.879129             1   31        120          270
# 131       0     1  0.886672             1   46        110          202
# 175       0     1  0.890947             1   43        140          288
# 161       0     1  0.897405             1   49        128          212
# 760       0     1  0.903078             1   53        123          282
# 577       0     1  0.903702             1   67        146          369
# 444       0     1  0.907921             1   56        120          100
# 494       0     1  0.909460             1   60        142          216
# 529       0     1  0.912161             1   72        143          211
# 600       1     1  0.918271             0   57        130          207
# 535       0     1  0.918944             1   56        130            0
# 887       0     1  0.938789             1   43        132          247
# 296       0     1  0.944842             1   50        145            0
# 538       0     1  0.945129             1   54        130          202
# 407       0     1  0.951655             1   62        115            0
# 584       0     1  0.953366             1   64        141          244
# 430       0     1  0.954164             1   57        128            0
#
#      FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  ChestPainType_ASY  \
# 126          0    190      0.0   True  False              False
# 9            0    120      0.0   True  False              False
# 64           0    145      0.0   True  False              False
# 234          0    140      0.0   True  False              False
# 467          0    130      0.1   True  False              False
# 228          0    170      0.0  False   True              False
# 162          0    174      0.0  False   True              False
# 12           0    145      0.0  False   True              False
# 171          0    188      0.0  False   True              False
# 684          0    152      0.0  False   True              False
# 282          0    160      2.0   True  False              False
# 843          1    162      1.0   True  False              False
# 661          0    126      0.8  False   True              False
# 560          0    137      0.2  False   True              False
# 629          0    159      0.0   True  False               True
# 639          1    159      0.0   True  False              False
# 110          0    124      1.0   True  False              False
# 655          0    181      0.0  False   True               True
# 270          0    140      0.0  False   True               True
# 30           0    130      0.0  False   True              False
# 850          0    145      6.2   True  False               True
# 302          1    120      1.5  False   True               True
# 383          0    156      0.0   True  False               True
# 41           0    100      0.0   True  False              False
# 581          0    159      1.5  False   True               True
# 88           0    155      0.0  False   True              False
# 811          0    122      1.0   True  False               True
# 626          0    111      0.0  False   True               True
# 469          1    161      2.0  False   True              False
# 372          0     98      0.0  False   True               True
# 492          0    145      3.0  False   True              False
# 585          1    120      0.8  False   True              False
# 516          1    132      0.0  False   True              False
# 820          1    178      1.2  False   True              False
# 637          0    181      1.2  False   True               True
# 327          1    119      0.9  False   True               True
# 335          1    134     -0.8  False   True              False
# 883          0    148      0.4  False   True               True
# 555          0    118      0.0  False   True              False
# 509          0    110      0.0  False   True               True
# 909          0    136      0.0   True  False               True
# 719          0    147      1.4  False   True               True
# 520          0    128      0.5  False   True               True
# 457          1    165      0.0  False   True               True
# 395          1    150      0.0  False   True               True
# 793          1    163      0.2  False   True               True
# 473          1    122      1.7  False   True              False
# 324          1    133     -2.6  False   True               True
# 350          1    120      0.0  False   True               True
# 718          1    124      1.0  False   True               True
# 842          1    136      3.0   True  False               True
# 56           0    153      1.5  False   True               True
# 131          0    150      0.0  False   True               True
# 175          0    135      2.0  False   True               True
# 161          0     96      0.0  False   True               True
# 760          0     95      2.0  False   True               True
# 577          0    110      1.9  False   True               True
# 444          0    120      1.5  False   True               True
# 494          0    110      2.5  False   True               True
# 529          0    109      1.4  False   True               True
# 600          0     96      1.0  False   True               True
# 535          0    122      1.0  False   True               True
# 887          1    143      0.1  False   True               True
# 296          1    139      0.7  False   True               True
# 538          1    112      2.0  False   True               True
# 407          1     72     -0.5  False   True               True
# 584          1    116      1.5  False   True               True
# 430          1    148      1.0  False   True               True
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  \
# 126               True              False             False           False
# 9                 True              False             False           False
# 64                True              False             False           False
# 234               True              False             False           False
# 467               True              False             False           False
# 228               True              False             False           False
# 162               True              False             False           False
# 12                True              False             False           False
# 171              False               True             False           False
# 684              False               True             False           False
# 282              False               True             False           False
# 843              False              False              True            True
# 661              False               True             False            True
# 560              False               True             False           False
# 629              False              False             False            True
# 639               True              False             False            True
# 110               True              False             False           False
# 655              False              False             False           False
# 270              False              False             False           False
# 30               False               True             False           False
# 850              False              False             False            True
# 302              False              False             False           False
# 383              False              False             False           False
# 41               False               True             False           False
# 581              False              False             False           False
# 88               False              False              True           False
# 811              False              False             False            True
# 626              False              False             False            True
# 469               True              False             False           False
# 372              False              False             False           False
# 492              False              False              True           False
# 585               True              False             False           False
# 516              False               True             False           False
# 820              False              False              True           False
# 637              False              False             False           False
# 327              False              False             False           False
# 335              False              False              True            True
# 883              False              False             False           False
# 555              False               True             False           False
# 509              False              False             False           False
# 909              False              False             False           False
# 719              False              False             False            True
# 520              False              False             False           False
# 457              False              False             False           False
# 395              False              False             False           False
# 793              False              False             False           False
# 473              False               True             False           False
# 324              False              False             False           False
# 350              False              False             False           False
# 718              False              False             False            True
# 842              False              False             False            True
# 56               False              False             False           False
# 131              False              False             False           False
# 175              False              False             False           False
# 161              False              False             False           False
# 760              False              False             False           False
# 577              False              False             False           False
# 444              False              False             False           False
# 494              False              False             False           False
# 529              False              False             False           False
# 600              False              False             False           False
# 535              False              False             False            True
# 887              False              False             False            True
# 296              False              False             False           False
# 538              False              False             False           False
# 407              False              False             False           False
# 584              False              False             False           False
# 430              False              False             False           False
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_N  ExerciseAngina_Y  \
# 126               True          False              True             False
# 9                 True          False              True             False
# 64                True          False              True             False
# 234              False           True              True             False
# 467               True          False              True             False
# 228               True          False              True             False
# 162               True          False              True             False
# 12                True          False              True             False
# 171               True          False              True             False
# 684               True          False              True             False
# 282               True          False             False              True
# 843              False          False              True             False
# 661              False          False              True             False
# 560              False           True              True             False
# 629              False          False              True             False
# 639              False          False             False              True
# 110               True          False              True             False
# 655               True          False              True             False
# 270               True          False              True             False
# 30                True          False              True             False
# 850              False          False              True             False
# 302               True          False              True             False
# 383               True          False              True             False
# 41               False           True             False              True
# 581               True          False             False              True
# 88               False           True              True             False
# 811              False          False              True             False
# 626              False          False             False              True
# 469               True          False              True             False
# 372               True          False             False              True
# 492              False           True              True             False
# 585              False           True              True             False
# 516               True          False              True             False
# 820               True          False              True             False
# 637               True          False              True             False
# 327               True          False             False              True
# 335              False          False              True             False
# 883               True          False              True             False
# 555              False           True             False              True
# 509               True          False              True             False
# 909               True          False             False              True
# 719              False          False              True             False
# 520              False           True              True             False
# 457               True          False              True             False
# 395               True          False              True             False
# 793               True          False              True             False
# 473              False           True             False              True
# 324              False           True              True             False
# 350               True          False              True             False
# 718              False          False              True             False
# 842              False          False             False              True
# 56                True          False             False              True
# 131               True          False             False              True
# 175               True          False             False              True
# 161               True          False             False              True
# 760               True          False             False              True
# 577               True          False             False              True
# 444               True          False             False              True
# 494               True          False             False              True
# 529               True          False             False              True
# 600              False           True             False              True
# 535              False          False             False              True
# 887              False          False             False              True
# 296               True          False             False              True
# 538               True          False             False              True
# 407               True          False             False              True
# 584              False           True             False              True
# 430              False           True             False              True
#
#      ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 126          False          False         True
# 9            False          False         True
# 64           False          False         True
# 234          False          False         True
# 467          False          False         True
# 228          False          False         True
# 162          False          False         True
# 12           False          False         True
# 171          False          False         True
# 684          False          False         True
# 282          False          False         True
# 843          False          False         True
# 661          False          False         True
# 560          False          False         True
# 629          False          False         True
# 639          False          False         True
# 110          False           True        False
# 655          False          False         True
# 270          False          False         True
# 30           False           True        False
# 850           True          False        False
# 302          False          False         True
# 383          False           True        False
# 41           False           True        False
# 581          False          False         True
# 88           False           True        False
# 811          False           True        False
# 626          False          False         True
# 469          False           True        False
# 372          False          False         True
# 492          False           True        False
# 585          False           True        False
# 516          False           True        False
# 820          False           True        False
# 637          False           True        False
# 327          False          False         True
# 335          False           True        False
# 883          False           True        False
# 555          False           True        False
# 509          False           True        False
# 909          False           True        False
# 719          False           True        False
# 520          False           True        False
# 457          False           True        False
# 395          False           True        False
# 793          False           True        False
# 473          False           True        False
# 324          False           True        False
# 350          False           True        False
# 718          False           True        False
# 842          False           True        False
# 56           False           True        False
# 131          False           True        False
# 175          False           True        False
# 161          False           True        False
# 760          False           True        False
# 577          False           True        False
# 444          False           True        False
# 494          False           True        False
# 529          False           True        False
# 600          False           True        False
# 535          False           True        False
# 887          False           True        False
# 296          False           True        False
# 538          False           True        False
# 407          False           True        False
# 584          False           True        False
# 430          False           True        False
